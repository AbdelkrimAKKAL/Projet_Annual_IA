# %% [markdown]
# # Cas de tests - Linear Model vs PMC

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'python')))

from model_linear import entrainer_linear, predire_linear, entrainer_linear_regression, predire_linear_regression, lib
from pmc import init, init_regression, entrainer, predire

# %%
COULEURS = ['blue', 'red', 'green'] 

def precision(predict_fn, X, Y):
    return 100 * sum(predict_fn(x) == y for x, y in zip(X, Y)) / len(X)

def frontiere(predict_fn, X, Y, titre):
    X = np.array(X, dtype=float)
    n = max(Y) + 1
    cmap = ListedColormap(COULEURS[:n])

    pas = 0.05
    vx = np.arange(X[:, 0].min() - 0.3, X[:, 0].max() + 0.3, pas)
    vy = np.arange(X[:, 1].min() - 0.3, X[:, 1].max() + 0.3, pas)
    Z = [[predict_fn([x, y]) for x in vx] for y in vy]
    plt.contourf(vx, vy, Z, levels=np.arange(-0.5, n), cmap=cmap, alpha=0.15)

    for classe in range(n):
        pts = X[[y == classe for y in Y]]
        plt.scatter(pts[:, 0], pts[:, 1], color=COULEURS[classe])
    plt.title(titre)
    plt.show()

def courbe(predict_fn, X, Y, titre):
    X_np = np.array(X, dtype=float)
    xs = np.linspace(X_np.min() - 0.5, X_np.max() + 0.5, 100)
    plt.scatter(X_np, Y)
    plt.plot(xs, [predict_fn([x]) for x in xs], color='orange')
    plt.title(titre)
    plt.show()

def points3d(predict_fn, X, Y, titre):
    X_np = np.array(X, dtype=float)
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.scatter(X_np[:, 0], X_np[:, 1], Y, color='blue', label='reel')
    ax.scatter(X_np[:, 0], X_np[:, 1], [predict_fn(x) for x in X], color='orange', label='predit')
    plt.title(titre)
    plt.legend()
    plt.show()

# %% [markdown]
# Trois fonctions rejouent le meme scenario (Linear puis MLP) sur un jeu de donnees :
# une pour la classification a 2 classes, une pour 3 classes, une pour la regression.

# %%
def test_binaire(X, Y_signe, nb, epochs_lin, lr_lin, cachees, epochs_mlp, alpha_mlp):
    Y_lab = [0 if y == 1 else 1 for y in Y_signe]  # 0 = classe "1" (bleu), 1 = classe "-1" (rouge)

    model = entrainer_linear(X, Y_lab, output_size=2, epochs=epochs_lin, lr=lr_lin)
    predict_lin = lambda p: predire_linear(model, p)
    frontiere(predict_lin, X, Y_lab, f"Linear - Cas {nb} ({precision(predict_lin, X, Y_lab):.0f}%)")
    lib.destroy_linear_model(model)

    init(2, cachees, 1)
    entrainer(X, [[y] for y in Y_signe], epochs=epochs_mlp, alpha=alpha_mlp)
    predict_mlp = lambda p: 0 if predire(p, 1)[0] >= 0 else 1
    frontiere(predict_mlp, X, Y_lab, f"MLP - Cas {nb} ({precision(predict_mlp, X, Y_lab):.0f}%)")


def test_multiclasse(X, Y, nb, nb_classes, epochs_lin, lr_lin, cachees, epochs_mlp, alpha_mlp):
    Y_lab = [int(np.argmax(y)) for y in Y]

    model = entrainer_linear(X, Y_lab, output_size=nb_classes, epochs=epochs_lin, lr=lr_lin)
    predict_lin = lambda p: predire_linear(model, p)
    frontiere(predict_lin, X, Y_lab, f"Linear - Cas {nb} ({precision(predict_lin, X, Y_lab):.0f}%)")
    lib.destroy_linear_model(model)

    init(2, cachees, nb_classes)
    entrainer(X, Y, epochs=epochs_mlp, alpha=alpha_mlp)
    predict_mlp = lambda p: int(np.argmax(predire(p, nb_classes)))
    frontiere(predict_mlp, X, Y_lab, f"MLP - Cas {nb} ({precision(predict_mlp, X, Y_lab):.0f}%)")


def test_regression(X, Y, nb, epochs_lin, lr_lin, cachees, epochs_mlp, alpha_mlp, plot):
    model = entrainer_linear_regression(X, Y, epochs=epochs_lin, lr=lr_lin)
    predict_lin = lambda p: predire_linear_regression(model, p)
    plot(predict_lin, X, Y, f"Linear - Cas {nb}")
    lib.destroy_linear_model(model)

    init_regression(len(X[0]), cachees, 1)
    entrainer(X, [[y] for y in Y], epochs=epochs_mlp, alpha=alpha_mlp)
    predict_mlp = lambda p: predire(p, 1)[0]
    plot(predict_mlp, X, Y, f"MLP - Cas {nb}")

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Cas 1 : Linear Simple -- attendu Linear OK, MLP OK

# %%
X = [[1, 1], [2, 3], [3, 3]]
Y = [1, -1, -1]
test_binaire(X, Y, nb=1, epochs_lin=1000, lr_lin=0.1, cachees=2, epochs_mlp=3000, alpha_mlp=0.1)

# %% [markdown]
# ### Cas 2 : Linear Multiple -- attendu Linear OK, MLP OK

# %%
X = np.concatenate([
    np.random.random((50, 2)) * 0.9 + np.array([1, 1]),
    np.random.random((50, 2)) * 0.9 + np.array([2, 2]),
]).tolist()
Y = (np.concatenate([np.ones((50,)), np.ones((50,)) * -1.0])).tolist()
test_binaire(X, Y, nb=2, epochs_lin=2000, lr_lin=0.01, cachees=2, epochs_mlp=3000, alpha_mlp=0.1)

# %% [markdown]
# ### Cas 3 : XOR -- attendu Linear KO, MLP OK

# %%
X = [[1, 0], [0, 1], [0, 0], [1, 1]]
Y = [1, 1, -1, -1]
test_binaire(X, Y, nb=3, epochs_lin=5000, lr_lin=0.01, cachees=2, epochs_mlp=10000, alpha_mlp=0.1)

# %% [markdown]
# ### Cas 4 : Cross -- attendu Linear KO, MLP OK

# %%
X = (np.random.random((500, 2)) * 2.0 - 1.0).tolist()
Y = [1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X]
test_binaire(X, Y, nb=4, epochs_lin=2000, lr_lin=0.01, cachees=8, epochs_mlp=5000, alpha_mlp=0.05)

# %% [markdown]
# ### Cas 5 : Multi Linear 3 classes - attendu Linear OK, MLP OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([
    [1, -1, -1] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else
    [-1, 1, -1] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else
    [-1, -1, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else
    [-1, -1, -1]
    for p in X
])
garde = [not np.all(arr == [-1, -1, -1]) for arr in Y]
X, Y = X[garde].tolist(), Y[garde].tolist()
test_multiclasse(X, Y, nb=5, nb_classes=3, epochs_lin=2000, lr_lin=0.01, cachees=4, epochs_mlp=5000, alpha_mlp=0.05)

# %% [markdown]
# ### Cas 6 : Multi Cross -- attendu Linear KO, MLP OK

# %%
X = (np.random.random((1000, 2)) * 2.0 - 1.0).tolist()
Y = [
    [1, -1, -1] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else
    [-1, 1, -1] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else
    [-1, -1, 1]
    for p in X
]
test_multiclasse(X, Y, nb=6, nb_classes=3, epochs_lin=2000, lr_lin=0.01, cachees=24, epochs_mlp=15000, alpha_mlp=0.005)

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Cas 1 : Linear Simple 2D -- attendu Linear OK, MLP OK

# %%
X = [[1], [2]]
Y = [2, 3]
test_regression(X, Y, nb=1, epochs_lin=2000, lr_lin=0.1, cachees=2, epochs_mlp=3000, alpha_mlp=0.1, plot=courbe)

# %% [markdown]
# ### Cas 2 : Non Linear Simple 2D -- attendu Linear OK, MLP OK

# %%
X = [[1], [2], [3]]
Y = [2, 3, 2.5]
test_regression(X, Y, nb=2, epochs_lin=2000, lr_lin=0.05, cachees=4, epochs_mlp=5000, alpha_mlp=0.05, plot=courbe)

# %% [markdown]
# ### Cas 3 : Linear Simple 3D -- attendu Linear OK, MLP OK

# %%
X = [[1, 1], [2, 2], [3, 1]]
Y = [2, 3, 2.5]
test_regression(X, Y, nb=3, epochs_lin=2000, lr_lin=0.05, cachees=2, epochs_mlp=3000, alpha_mlp=0.05, plot=points3d)

# %% [markdown]
# ### Cas 4 : Linear Tricky 3D -- attendu Linear OK, MLP OK

# %%
X = [[1, 1], [2, 2], [3, 3]]
Y = [1, 2, 3]
test_regression(X, Y, nb=4, epochs_lin=2000, lr_lin=0.05, cachees=2, epochs_mlp=3000, alpha_mlp=0.05, plot=points3d)

# %% [markdown]
# ### Cas 5 : Non Linear Simple 3D -- attendu Linear KO, MLP OK
#
# (structure XOR : aucun plan ne peut passer pres des 4 points a la fois)

# %%
X = [[1, 0], [0, 1], [1, 1], [0, 0]]
Y = [2, 1, -2, -1]
test_regression(X, Y, nb=5, epochs_lin=2000, lr_lin=0.05, cachees=2, epochs_mlp=8000, alpha_mlp=0.1, plot=points3d)
